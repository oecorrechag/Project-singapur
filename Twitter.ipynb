# %%
import pandas as pd

# %%
df = pd.read_csv('data/tweets_marioBross.csv')
df.head()
# Out:
#                   created_at  \
# 0  2022-09-24 23:59:27+00:00
# 1  2022-09-24 23:58:57+00:00
# 2  2022-09-24 23:58:40+00:00
# 3  2022-09-24 23:58:38+00:00
# 4  2022-09-24 23:58:34+00:00
#
#                                                 text                   source  \
# 0  RT @SigmaPosting: Sigmoad\n\nSource: Toad\nSup...       Twitter for iPhone
# 1                       super mario bros but its gay  Cheap Bots, Done Quick!
# 2  RT @LightsCameraPod: 🚨 BREAKING 🚨\n\nThe first...       Twitter for iPhone
# 3  RT @_troIlface: 🚨 BREAKING 🚨\n\nThe first audi...          Twitter Web App
# 4  RT @DidjSonic: 🚨 BREAKING 🚨\n\nA Super Mario B...      Twitter for Android
#
#                               name         username     location  verified  \
# 0  Jordan 'Kūfuku no akuma' Thorne         jrdnthrn  Seattle, WA     False
# 1                          Gay Bot     butitsgaybot          NaN     False
# 2                    Adrian Torres  adrianwankenobi          NaN     False
# ...
